# %%
import pandas as pd

# %%
df = pd.read_csv("dataprak1.csv")

# %%
df
# Out:
#    Nama;Gender;Angkatan ;Tinggi (cm);Waktu Perjalanan (menit);Wilayah Tinggal
# 0                        Rafiq ;L;2023;179;45;jakarta
# 1                         Rayyan;L;2023;175;50;bekasi
# 2                          Dito;L;2023;165;40;jakarta
# 3                     Daniel;L;2023;168;45;tanggerang
# 4                          Esti;P;2023;173;30;jakarta
# 5                         Noval;L;2023;178;35;jakarta
# 6                          Wulan;P;2023;156;45;bekasi
# 7                           Alice;P;2023;155;55;depok
# 8                          Sukri;L;2023;177;50;bekasi
# 9                          Acel;P;2023;159;60;jakarta
# 10                        Toddy;L;2023;176;40;jakarta
# 11                        Hanzo;L;2023;172;45;jakarta
# 12                         Jhon;L;2023;173;25;jakarta
# 13                         Lily;P;2023;163;30;jakarta
# 14                         Putra;L;2023;170;15;bekasi
# 15                         Tonny;L;2023;176;35;bekasi
# ...

# %%
df = pd.read_csv("dataxlprak1.csv",sep =';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = pd.read_csv("dataxlprak1.csv",sep =';')
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("dataxlprak1.csv",sep=';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df = pd.read_csv("dataxlprak1.csv",sep=';')
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("data_xlprak1.csv",sep=';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df = pd.read_csv("data_xlprak1.csv",sep=';')
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_excel("data_xlprak1.xlsx")

# %%
df
# Out:
#       Nama Gender  Angkatan   Tinggi (cm)  Waktu Perjalanan (menit)  \
# 0   Rafiq       L       2023          179                        45
# 1   Rayyan      L       2023          175                        50
# 2     Dito      L       2023          165                        40
# 3   Daniel      L       2023          168                        45
# 4     Esti      P       2023          173                        30
# 5    Noval      L       2023          178                        35
# 6    Wulan      P       2023          156                        45
# 7    Alice      P       2023          155                        55
# 8    Sukri      L       2023          177                        50
# 9     Acel      P       2023          159                        60
# 10   Toddy      L       2023          176                        40
# 11   Hanzo      L       2023          172                        45
# 12    Jhon      L       2023          173                        25
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("dataprak1.csv",sep=';')

# %%
df
# Out:
#       Nama Gender  Angkatan   Tinggi (cm)  Waktu Perjalanan (menit)  \
# 0   Rafiq       L       2023          179                        45
# 1   Rayyan      L       2023          175                        50
# 2     Dito      L       2023          165                        40
# 3   Daniel      L       2023          168                        45
# 4     Esti      P       2023          173                        30
# 5    Noval      L       2023          178                        35
# 6    Wulan      P       2023          156                        45
# 7    Alice      P       2023          155                        55
# 8    Sukri      L       2023          177                        50
# 9     Acel      P       2023          159                        60
# 10   Toddy      L       2023          176                        40
# 11   Hanzo      L       2023          172                        45
# 12    Jhon      L       2023          173                        25
# ...

# %%
data_nama = read.csv("C:/SMT Antara/PrakStatistika/BahanPraktikum1_Statistika.csv “)
# Out:
#   Cell In[24], line 1
#     data_nama = read.csv("C:/SMT Antara/PrakStatistika/BahanPraktikum1_Statistika.csv “)
#                          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
data_nama = read.csv("C:\Users\HP\Desktop\Probabilitas Statistika\dataprak1.csv")
# Out:
#   Cell In[25], line 1
#     data_nama = read.csv("C:\Users\HP\Desktop\Probabilitas Statistika\dataprak1.csv")
#                                                                                     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
data_nama = read.csv("C:/Users/HP/Desktop/Probabilitas Statistika/dataprak1.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 data_nama = read.csv("C:/Users/HP/Desktop/Probabilitas Statistika/dataprak1.csv")
#
# NameError: name 'read' is not defined

# %%
data_nama = read.csv("C:/Users/HP/Desktop/Probabilitas Statistika.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 data_nama = read.csv("C:/Users/HP/Desktop/Probabilitas Statistika.csv")
#
# NameError: name 'read' is not defined

# %%
import pandas as pd

# %%
data_nama = read.csv("C:/Users/HP/Desktop/Probabilitas Statistika/dataprak1.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 data_nama = read.csv("C:/Users/HP/Desktop/Probabilitas Statistika/dataprak1.csv")
#
# NameError: name 'read' is not defined

# %%
import pandas as pd
data_nama = pd.read_csv("C:/Users/HP/Desktop/Probabilitas Statistika/dataprak1.csv")
